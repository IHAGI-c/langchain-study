# %% [markdown]
# # langchain 환경 셋팅
#
# ## 1. pyenv 설치
# 참고 링크: https://github.com/pyenv/pyenv?tab=readme-ov-file#understanding-python-version-selection
# ```bash
# brew update
# brew install pyenv
# ```
# 아래의 내용을 터미널에 복사 + 붙혀넣기
# ```bash
# echo 'export PYENV_ROOT="$HOME/.pyenv"' >> ~/.zshrc
# echo '[[ -d $PYENV_ROOT/bin ]] && export PATH="$PYENV_ROOT/bin:$PATH"' >> ~/.zshrc
# echo 'eval "$(pyenv init -)"' >> ~/.zshrc
# ```
# (위의 코드 실행시 오류가 발생하는 경우)
#
# ```bash
# sudo chown $USER ~/.zshrc
# echo 'export PYENV_ROOT="$HOME/.pyenv"' >> ~/.zshrc
# echo '[[ -d $PYENV_ROOT/bin ]] && export PATH="$PYENV_ROOT/bin:$PATH"' >> ~/.zshrc
# echo 'eval "$(pyenv init -)"' >> ~/.zshrc
# ```
# 터미널 쉘을 재시작 합니다.
# ```bash
# exec "$SHELL"
# ```
#
#
# ---
#
# ## 2. python 설치
# 파이썬 3.11 버전 설치
# ```bash
# pyenv install 3.11
# ```
# 3.11 버전의 python 설정
# ```bash
# pyenv global 3.11
# exec zsh
# ```
# 파이썬 버전 확인
# ```bash
# python --version
# ```
# 3.11.9 버전이 설치되어야 함
#
#
# ---
#
#
# ## 3. poetry 설치
# 참고 링크: https://python-poetry.org/docs/#installing-with-the-official-installer
#
# poetry 설치
# ```bash
# pip3 install poetry
# ```
# 다운로드 받은 폴더로 이동
# ```bash
# cd langchain-study
# ```
# 파이썬 가상환경 설정
# ```bash
# poetry shell
# ```
# 파이썬 패키지 일괄 업데이트
# ```bash
# poetry update
#
# ```
